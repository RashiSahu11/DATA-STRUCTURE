# %% [markdown]
# STRING

# %%
name=("Rashi")
print(name[:2])
# Out:
# Ra

# %%
#String concentation
x='Beautiful'
y='hey'
print(y+x)
# Out:
# heyBeautiful

# %%
#string multiplication
a='he'
print(a*6)
# Out:
# hehehehehehe

# %%
#all letterws capital
x.upper()
# Out:
# 'BEAUTIFUL'

# %%
#all letters samll
x.lower()
# Out:
# 'beautiful'

# %%
#capitalize first letter of word
x.capitalize()
# Out:
# 'Beautiful'

# %%
# capitalize the first letter of all words
a='Rashi is the best girllll'
a.title()
# Out:
# 'Rashi Is The Best Girllll'

# %%
poem='''johny johny yess papa
eating sugar no papa
telling a lie no papa
open you mouth hahaha'''
print(poem)
# Out:
# johny johny yess papa
# eating sugar no papa
# telling a lie no papa
# open you mouth hahaha

# %%
poem.find('papa')
# Out:
# 17

# %%
p=poem.replace('papa','father').replace('sugar','brownie').replace('eating','drinking').replace('hahaha','eheheh')
print(p)
# Out:
# johny johny yess father
# drinking brownie no father
# telling a lie no father
# open you mouth eheheh

# %%
a.split()
# Out:
# ['Rashi', 'is', 'best', 'girllll']

# %%
p.splitlines()
# Out:
# ['johny johny yess father',
#  'drinking brownie no father',
#  'telling a lie no father',
#  'open you mouth eheheh']

# %%
text='  helloo    '
text.strip() #removes whitespaces
# Out:
# 'helloo'

# %%
p.count('e')# to check frequency of a letter
# Out:
# 11

# %%
a.startswith('a')
# Out:
# False

# %%
a.startswith('R')
# Out:
# True

# %%
a.endswith('l')
# Out:
# True

# %%
'hello'.isalpha()
# Out:
# True

# %%
'123'.isdigit()
# Out:
# True

# %%
'hello123'.isalnum()
# Out:
# True

# %%
'Hello World'.swapcase()
# Out:
# 'hELLO wORLD'

# %%
'hello'.index('l')
# Out:
# 2

# %%
len(p)
# Out:
# 96

# %%
text='Data'
print(text[::-1])
# Out:
# ataD
